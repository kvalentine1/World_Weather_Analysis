# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to find nearest city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# %%
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 784

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cea431afc5c9d7f46557ce6c37789ad5

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_wx_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_wx_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | buchanan
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 1 | gualdo tadino
# Processing Record 8 of Set 1 | thompson
# Processing Record 9 of Set 1 | henties bay
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | banda aceh
# Processing Record 12 of Set 1 | victoria
# Processing Record 13 of Set 1 | namatanai
# Processing Record 14 of Set 1 | paita
# Processing Record 15 of Set 1 | kruisfontein
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | necochea
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | pangai
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | christchurch
# Processing Record 25 of Set 1 | kenai
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | alingsas
# Processing Record 30 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | hasaki
# Processing Record 33 of Set 1 | kefalos
# Processing Record 34 of Set 1 | aloleng
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | bilibino
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | bentiu
# Processing Record 39 of Set 1 | skagastrond
# City not found. Skipping...
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | baykit
# Processing Record 43 of Set 1 | prince rupert
# Processing Record 44 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 1 | salinas
# Processing Record 46 of Set 1 | cabo san lucas
# Processing Record 47 of Set 1 | atar
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | gangotri
# City not found. Skipping...
# Processing Record 50 of Set 1 | valdez
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | iqaluit
# Processing Record 4 of Set 2 | winslow
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | tabat
# Processing Record 7 of Set 2 | yarada
# Processing Record 8 of Set 2 | yar-sale
# Processing Record 9 of Set 2 | santiago del estero
# Processing Record 10 of Set 2 | rio gallegos
# Processing Record 11 of Set 2 | faanui
# Processing Record 12 of Set 2 | xining
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | pisco
# Processing Record 16 of Set 2 | santa isabel
# Processing Record 17 of Set 2 | vila do maio
# Processing Record 18 of Set 2 | turukhansk
# Processing Record 19 of Set 2 | nieuwpoort
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | adrar
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | dillon
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | schieder-schwalenberg
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | borogontsy
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | matam
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | waddan
# Processing Record 34 of Set 2 | izhma
# Processing Record 35 of Set 2 | mul
# Processing Record 36 of Set 2 | lengshuijiang
# Processing Record 37 of Set 2 | vilhena
# Processing Record 38 of Set 2 | nishihara
# Processing Record 39 of Set 2 | shelburne
# Processing Record 40 of Set 2 | leninskoye
# Processing Record 41 of Set 2 | fort nelson
# Processing Record 42 of Set 2 | lakatoro
# Processing Record 43 of Set 2 | abha
# Processing Record 44 of Set 2 | sawtell
# Processing Record 45 of Set 2 | gat
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | airai
# Processing Record 49 of Set 2 | lagos
# Processing Record 50 of Set 2 | boa vista
# Processing Record 1 of Set 3 | mogok
# Processing Record 2 of Set 3 | burgeo
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | bay roberts
# Processing Record 5 of Set 3 | theog
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | richards bay
# Processing Record 9 of Set 3 | costache negri
# Processing Record 10 of Set 3 | opuwo
# Processing Record 11 of Set 3 | stornoway
# Processing Record 12 of Set 3 | strezhevoy
# Processing Record 13 of Set 3 | shadrinsk
# Processing Record 14 of Set 3 | road town
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | creel
# Processing Record 17 of Set 3 | puerto ayacucho
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 3 | east london
# Processing Record 21 of Set 3 | buin
# Processing Record 22 of Set 3 | bad sankt leonhard
# City not found. Skipping...
# Processing Record 23 of Set 3 | barrow
# Processing Record 24 of Set 3 | dubna
# Processing Record 25 of Set 3 | guapiles
# Processing Record 26 of Set 3 | coihaique
# Processing Record 27 of Set 3 | oranjemund
# Processing Record 28 of Set 3 | jamestown
# Processing Record 29 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 3 | vaini
# Processing Record 31 of Set 3 | ardakan
# Processing Record 32 of Set 3 | sitka
# Processing Record 33 of Set 3 | ilulissat
# Processing Record 34 of Set 3 | bungoma
# Processing Record 35 of Set 3 | shingu
# Processing Record 36 of Set 3 | katsuura
# Processing Record 37 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 3 | deer lake
# Processing Record 39 of Set 3 | opelousas
# Processing Record 40 of Set 3 | pevek
# Processing Record 41 of Set 3 | morant bay
# Processing Record 42 of Set 3 | yook
# Processing Record 43 of Set 3 | bolshaya rechka
# Processing Record 44 of Set 3 | grand gaube
# Processing Record 45 of Set 3 | jardim
# Processing Record 46 of Set 3 | sao felix do xingu
# Processing Record 47 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 48 of Set 3 | buala
# Processing Record 49 of Set 3 | carnarvon
# Processing Record 50 of Set 3 | ribeira grande
# Processing Record 1 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 4 | ratnagiri
# Processing Record 3 of Set 4 | bonavista
# Processing Record 4 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 4 | pychas
# Processing Record 7 of Set 4 | port lincoln
# Processing Record 8 of Set 4 | narsaq
# Processing Record 9 of Set 4 | taseyevo
# Processing Record 10 of Set 4 | mahebourg
# Processing Record 11 of Set 4 | huarmey
# Processing Record 12 of Set 4 | omsukchan
# Processing Record 13 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 4 | itoman
# Processing Record 15 of Set 4 | bethel
# Processing Record 16 of Set 4 | tulun
# Processing Record 17 of Set 4 | agadez
# Processing Record 18 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 4 | porto torres
# Processing Record 20 of Set 4 | souillac
# Processing Record 21 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 4 | bulgan
# Processing Record 23 of Set 4 | cherskiy
# Processing Record 24 of Set 4 | norman wells
# Processing Record 25 of Set 4 | sao filipe
# Processing Record 26 of Set 4 | saint george
# Processing Record 27 of Set 4 | nikolskoye
# Processing Record 28 of Set 4 | hamilton
# Processing Record 29 of Set 4 | chuy
# Processing Record 30 of Set 4 | asahikawa
# Processing Record 31 of Set 4 | katobu
# Processing Record 32 of Set 4 | tungor
# Processing Record 33 of Set 4 | batemans bay
# Processing Record 34 of Set 4 | maumere
# Processing Record 35 of Set 4 | ayan
# Processing Record 36 of Set 4 | talnakh
# Processing Record 37 of Set 4 | marevo
# Processing Record 38 of Set 4 | esso
# Processing Record 39 of Set 4 | krasnyy oktyabr
# Processing Record 40 of Set 4 | komsomolskiy
# Processing Record 41 of Set 4 | taltal
# Processing Record 42 of Set 4 | kula
# Processing Record 43 of Set 4 | tuktoyaktuk
# Processing Record 44 of Set 4 | esperance
# Processing Record 45 of Set 4 | coahuayana
# Processing Record 46 of Set 4 | bathsheba
# Processing Record 47 of Set 4 | abhar
# Processing Record 48 of Set 4 | himare
# Processing Record 49 of Set 4 | scarborough
# Processing Record 50 of Set 4 | gondanglegi
# Processing Record 1 of Set 5 | muroto
# Processing Record 2 of Set 5 | diapaga
# Processing Record 3 of Set 5 | gonen
# Processing Record 4 of Set 5 | port shepstone
# Processing Record 5 of Set 5 | kavieng
# Processing Record 6 of Set 5 | kodiak
# Processing Record 7 of Set 5 | casas grandes
# Processing Record 8 of Set 5 | lata
# Processing Record 9 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 5 | mendi
# Processing Record 11 of Set 5 | georgetown
# Processing Record 12 of Set 5 | lisakovsk
# Processing Record 13 of Set 5 | nouakchott
# Processing Record 14 of Set 5 | luanda
# Processing Record 15 of Set 5 | port hedland
# Processing Record 16 of Set 5 | lagoa
# Processing Record 17 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 18 of Set 5 | saint-georges
# Processing Record 19 of Set 5 | kropotkin
# Processing Record 20 of Set 5 | acapulco
# Processing Record 21 of Set 5 | flinders
# Processing Record 22 of Set 5 | honavar
# Processing Record 23 of Set 5 | aldan
# Processing Record 24 of Set 5 | comodoro rivadavia
# Processing Record 25 of Set 5 | balakhta
# Processing Record 26 of Set 5 | ambon
# Processing Record 27 of Set 5 | ust-tsilma
# Processing Record 28 of Set 5 | nemuro
# Processing Record 29 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 5 | mahajanga
# Processing Record 31 of Set 5 | kjollefjord
# Processing Record 32 of Set 5 | wanning
# Processing Record 33 of Set 5 | husavik
# Processing Record 34 of Set 5 | bataipora
# Processing Record 35 of Set 5 | touros
# Processing Record 36 of Set 5 | nalut
# Processing Record 37 of Set 5 | safotu
# Processing Record 38 of Set 5 | codrington
# Processing Record 39 of Set 5 | cockburn town
# Processing Record 40 of Set 5 | phuket
# Processing Record 41 of Set 5 | tuatapere
# Processing Record 42 of Set 5 | linxia
# Processing Record 43 of Set 5 | dargaville
# Processing Record 44 of Set 5 | hervey bay
# Processing Record 45 of Set 5 | pullman
# Processing Record 46 of Set 5 | rondonopolis
# Processing Record 47 of Set 5 | marsh harbour
# Processing Record 48 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 5 | teneguiban
# City not found. Skipping...
# Processing Record 50 of Set 5 | sabang
# Processing Record 1 of Set 6 | mehamn
# Processing Record 2 of Set 6 | ahipara
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | la cruz
# Processing Record 5 of Set 6 | clyde river
# Processing Record 6 of Set 6 | prainha
# Processing Record 7 of Set 6 | robertsport
# Processing Record 8 of Set 6 | taburbah
# City not found. Skipping...
# Processing Record 9 of Set 6 | westport
# Processing Record 10 of Set 6 | north bend
# Processing Record 11 of Set 6 | amapa
# Processing Record 12 of Set 6 | wang saphung
# Processing Record 13 of Set 6 | vostok
# Processing Record 14 of Set 6 | huallanca
# Processing Record 15 of Set 6 | dwarka
# Processing Record 16 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 17 of Set 6 | valparaiso
# Processing Record 18 of Set 6 | oyama
# Processing Record 19 of Set 6 | karaton
# Processing Record 20 of Set 6 | rio grande
# Processing Record 21 of Set 6 | coro
# Processing Record 22 of Set 6 | ngunguru
# Processing Record 23 of Set 6 | provideniya
# Processing Record 24 of Set 6 | presidencia roque saenz pena
# Processing Record 25 of Set 6 | le port
# Processing Record 26 of Set 6 | mineiros
# Processing Record 27 of Set 6 | deputatskiy
# Processing Record 28 of Set 6 | burns lake
# Processing Record 29 of Set 6 | alamos
# Processing Record 30 of Set 6 | alugan
# Processing Record 31 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 6 | hostotipaquillo
# Processing Record 33 of Set 6 | ketchikan
# Processing Record 34 of Set 6 | san cristobal
# Processing Record 35 of Set 6 | fonte boa
# Processing Record 36 of Set 6 | amalapuram
# Processing Record 37 of Set 6 | ostersund
# Processing Record 38 of Set 6 | monkey hill
# Processing Record 39 of Set 6 | pekalongan
# Processing Record 40 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 6 | kajaani
# Processing Record 42 of Set 6 | ancud
# Processing Record 43 of Set 6 | uwayl
# City not found. Skipping...
# Processing Record 44 of Set 6 | aklavik
# Processing Record 45 of Set 6 | ukiah
# Processing Record 46 of Set 6 | wajima
# Processing Record 47 of Set 6 | alpoyeca
# Processing Record 48 of Set 6 | portland
# Processing Record 49 of Set 6 | longyearbyen
# Processing Record 50 of Set 6 | kapit
# Processing Record 1 of Set 7 | karratha
# Processing Record 2 of Set 7 | asyut
# Processing Record 3 of Set 7 | leningradskiy
# Processing Record 4 of Set 7 | la ronge
# Processing Record 5 of Set 7 | sao joao da barra
# Processing Record 6 of Set 7 | kuching
# Processing Record 7 of Set 7 | port macquarie
# Processing Record 8 of Set 7 | mazara del vallo
# Processing Record 9 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 7 | sakakah
# Processing Record 11 of Set 7 | winton
# Processing Record 12 of Set 7 | manyana
# Processing Record 13 of Set 7 | bozoum
# Processing Record 14 of Set 7 | teguldet
# Processing Record 15 of Set 7 | san fernando
# Processing Record 16 of Set 7 | genhe
# Processing Record 17 of Set 7 | hovd
# Processing Record 18 of Set 7 | muisne
# Processing Record 19 of Set 7 | raudeberg
# Processing Record 20 of Set 7 | klaksvik
# Processing Record 21 of Set 7 | marzuq
# Processing Record 22 of Set 7 | dibulla
# Processing Record 23 of Set 7 | okhotsk
# Processing Record 24 of Set 7 | male
# Processing Record 25 of Set 7 | namie
# Processing Record 26 of Set 7 | chapais
# Processing Record 27 of Set 7 | lompoc
# Processing Record 28 of Set 7 | payo
# Processing Record 29 of Set 7 | byron bay
# Processing Record 30 of Set 7 | den helder
# Processing Record 31 of Set 7 | inhambane
# Processing Record 32 of Set 7 | boma
# Processing Record 33 of Set 7 | jining
# Processing Record 34 of Set 7 | torbay
# Processing Record 35 of Set 7 | saint-francois
# Processing Record 36 of Set 7 | saldanha
# Processing Record 37 of Set 7 | bac lieu
# Processing Record 38 of Set 7 | tigil
# Processing Record 39 of Set 7 | humaita
# Processing Record 40 of Set 7 | alice springs
# Processing Record 41 of Set 7 | singarayakonda
# Processing Record 42 of Set 7 | alirajpur
# Processing Record 43 of Set 7 | chiredzi
# Processing Record 44 of Set 7 | bagotville
# Processing Record 45 of Set 7 | okha
# Processing Record 46 of Set 7 | ipora
# Processing Record 47 of Set 7 | hithadhoo
# Processing Record 48 of Set 7 | naze
# Processing Record 49 of Set 7 | jacareacanga
# Processing Record 50 of Set 7 | basco
# Processing Record 1 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 8 | zonguldak
# Processing Record 4 of Set 8 | kilingi-nomme
# Processing Record 5 of Set 8 | black river
# Processing Record 6 of Set 8 | marana
# Processing Record 7 of Set 8 | baruun-urt
# Processing Record 8 of Set 8 | porto novo
# Processing Record 9 of Set 8 | tabou
# Processing Record 10 of Set 8 | cap malheureux
# Processing Record 11 of Set 8 | kahului
# Processing Record 12 of Set 8 | tiznit
# Processing Record 13 of Set 8 | harper
# Processing Record 14 of Set 8 | stirion
# Processing Record 15 of Set 8 | khatanga
# Processing Record 16 of Set 8 | arenapolis
# Processing Record 17 of Set 8 | lakes entrance
# Processing Record 18 of Set 8 | lalibela
# Processing Record 19 of Set 8 | xai-xai
# Processing Record 20 of Set 8 | saskylakh
# Processing Record 21 of Set 8 | chanika
# Processing Record 22 of Set 8 | gornopravdinsk
# Processing Record 23 of Set 8 | ikalamavony
# Processing Record 24 of Set 8 | sioux lookout
# Processing Record 25 of Set 8 | lyngdal
# Processing Record 26 of Set 8 | brockville
# Processing Record 27 of Set 8 | noumea
# Processing Record 28 of Set 8 | mazamari
# Processing Record 29 of Set 8 | bafra
# Processing Record 30 of Set 8 | arraias
# Processing Record 31 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 8 | kimbe
# Processing Record 33 of Set 8 | jawhar
# Processing Record 34 of Set 8 | pangnirtung
# Processing Record 35 of Set 8 | sinnamary
# Processing Record 36 of Set 8 | qom
# Processing Record 37 of Set 8 | olinda
# Processing Record 38 of Set 8 | sylvan lake
# Processing Record 39 of Set 8 | aykhal
# Processing Record 40 of Set 8 | mantua
# Processing Record 41 of Set 8 | ayni
# Processing Record 42 of Set 8 | tete
# Processing Record 43 of Set 8 | cayenne
# Processing Record 44 of Set 8 | the valley
# Processing Record 45 of Set 8 | college
# Processing Record 46 of Set 8 | marawi
# Processing Record 47 of Set 8 | canutama
# Processing Record 48 of Set 8 | suntar
# Processing Record 49 of Set 8 | dalian
# Processing Record 50 of Set 8 | waingapu
# Processing Record 1 of Set 9 | bardiyah
# Processing Record 2 of Set 9 | lorengau
# Processing Record 3 of Set 9 | lavrentiya
# Processing Record 4 of Set 9 | andenes
# Processing Record 5 of Set 9 | gasa
# Processing Record 6 of Set 9 | swift current
# Processing Record 7 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 9 | russell
# Processing Record 9 of Set 9 | santa cruz del sur
# Processing Record 10 of Set 9 | denpasar
# Processing Record 11 of Set 9 | vestmanna
# Processing Record 12 of Set 9 | cochabamba
# Processing Record 13 of Set 9 | bowen
# Processing Record 14 of Set 9 | huntington beach
# Processing Record 15 of Set 9 | fukue
# Processing Record 16 of Set 9 | waw
# Processing Record 17 of Set 9 | kulhudhuffushi
# Processing Record 18 of Set 9 | arman
# Processing Record 19 of Set 9 | nanga eboko
# Processing Record 20 of Set 9 | tyazhinskiy
# Processing Record 21 of Set 9 | tucuma
# Processing Record 22 of Set 9 | luderitz
# Processing Record 23 of Set 9 | show low
# Processing Record 24 of Set 9 | varangaon
# Processing Record 25 of Set 9 | sernur
# Processing Record 26 of Set 9 | abilene
# Processing Record 27 of Set 9 | samarai
# Processing Record 28 of Set 9 | kurilsk
# Processing Record 29 of Set 9 | mitsamiouli
# Processing Record 30 of Set 9 | barroualie
# City not found. Skipping...
# Processing Record 31 of Set 9 | pabrade
# Processing Record 32 of Set 9 | nha trang
# Processing Record 33 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 9 | kosgi
# City not found. Skipping...
# Processing Record 35 of Set 9 | luba
# Processing Record 36 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 9 | qesarya
# Processing Record 38 of Set 9 | akyab
# Processing Record 39 of Set 9 | kutum
# Processing Record 40 of Set 9 | stony plain
# Processing Record 41 of Set 9 | issenye
# Processing Record 42 of Set 9 | high level
# Processing Record 43 of Set 9 | pochutla
# Processing Record 44 of Set 9 | san andres
# Processing Record 45 of Set 9 | uribia
# Processing Record 46 of Set 9 | tiksi
# Processing Record 47 of Set 9 | porto velho
# Processing Record 48 of Set 9 | anchorage
# Processing Record 49 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 9 | sorland
# Processing Record 1 of Set 10 | slave lake
# Processing Record 2 of Set 10 | nouadhibou
# Processing Record 3 of Set 10 | minuri
# Processing Record 4 of Set 10 | hofn
# Processing Record 5 of Set 10 | rafai
# Processing Record 6 of Set 10 | wangqing
# Processing Record 7 of Set 10 | aguililla
# Processing Record 8 of Set 10 | chokurdakh
# Processing Record 9 of Set 10 | yeniseysk
# Processing Record 10 of Set 10 | evensk
# Processing Record 11 of Set 10 | nanortalik
# Processing Record 12 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 10 | bereda
# Processing Record 14 of Set 10 | severo-kurilsk
# Processing Record 15 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 10 | general pico
# Processing Record 17 of Set 10 | sivas
# Processing Record 18 of Set 10 | guerrero negro
# Processing Record 19 of Set 10 | atambua
# Processing Record 20 of Set 10 | los llanos de aridane
# Processing Record 21 of Set 10 | mporokoso
# Processing Record 22 of Set 10 | smithers
# Processing Record 23 of Set 10 | prokudskoye
# Processing Record 24 of Set 10 | tanem
# Processing Record 25 of Set 10 | kungurtug
# Processing Record 26 of Set 10 | kismayo
# Processing Record 27 of Set 10 | tagusao
# Processing Record 28 of Set 10 | puerto cabezas
# Processing Record 29 of Set 10 | tabukiniberu
# City not found. Skipping...
# Processing Record 30 of Set 10 | amahai
# Processing Record 31 of Set 10 | sug-aksy
# City not found. Skipping...
# Processing Record 32 of Set 10 | balashov
# Processing Record 33 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 10 | hambantota
# Processing Record 35 of Set 10 | boyuibe
# Processing Record 36 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 37 of Set 10 | sao gabriel da cachoeira
# Processing Record 38 of Set 10 | pitimbu
# Processing Record 39 of Set 10 | ko samui
# Processing Record 40 of Set 10 | guerande
# Processing Record 41 of Set 10 | villamontes
# Processing Record 42 of Set 10 | nisporeni
# Processing Record 43 of Set 10 | port-cartier
# Processing Record 44 of Set 10 | san carlos del zulia
# Processing Record 45 of Set 10 | lebanon
# Processing Record 46 of Set 10 | gossas
# Processing Record 47 of Set 10 | port hardy
# Processing Record 48 of Set 10 | bambanglipuro
# Processing Record 49 of Set 10 | shaunavon
# Processing Record 50 of Set 10 | san rafael
# Processing Record 1 of Set 11 | lazaro cardenas
# Processing Record 2 of Set 11 | olafsvik
# Processing Record 3 of Set 11 | vila velha
# Processing Record 4 of Set 11 | north platte
# Processing Record 5 of Set 11 | coos bay
# Processing Record 6 of Set 11 | porto tolle
# Processing Record 7 of Set 11 | arlit
# Processing Record 8 of Set 11 | manzhouli
# Processing Record 9 of Set 11 | japura
# Processing Record 10 of Set 11 | bandarbeyla
# Processing Record 11 of Set 11 | rehoboth
# Processing Record 12 of Set 11 | falam
# Processing Record 13 of Set 11 | mount isa
# Processing Record 14 of Set 11 | brae
# Processing Record 15 of Set 11 | orsha
# Processing Record 16 of Set 11 | churapcha
# Processing Record 17 of Set 11 | rosarito
# Processing Record 18 of Set 11 | uarini
# Processing Record 19 of Set 11 | moerai
# Processing Record 20 of Set 11 | burnie
# Processing Record 21 of Set 11 | eyl
# Processing Record 22 of Set 11 | usinsk
# Processing Record 23 of Set 11 | duluth
# Processing Record 24 of Set 11 | general roca
# Processing Record 25 of Set 11 | chamonix-mont-blanc
# Processing Record 26 of Set 11 | seydi
# Processing Record 27 of Set 11 | oistins
# Processing Record 28 of Set 11 | novyy urgal
# Processing Record 29 of Set 11 | kalabo
# Processing Record 30 of Set 11 | yelabuga
# Processing Record 31 of Set 11 | blackburn
# Processing Record 32 of Set 11 | rodrigues alves
# Processing Record 33 of Set 11 | nome
# Processing Record 34 of Set 11 | pasni
# Processing Record 35 of Set 11 | husum
# Processing Record 36 of Set 11 | vedaranniyam
# City not found. Skipping...
# Processing Record 37 of Set 11 | saint anthony
# Processing Record 38 of Set 11 | morwa
# Processing Record 39 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 11 | pedasi
# Processing Record 42 of Set 11 | bilma
# Processing Record 43 of Set 11 | sri aman
# Processing Record 44 of Set 11 | cullera
# Processing Record 45 of Set 11 | kaitong
# Processing Record 46 of Set 11 | shache
# Processing Record 47 of Set 11 | encruzilhada do sul
# Processing Record 48 of Set 11 | ulverstone
# Processing Record 49 of Set 11 | tazovskiy
# Processing Record 50 of Set 11 | kenora
# Processing Record 1 of Set 12 | trairi
# Processing Record 2 of Set 12 | jibuti
# Processing Record 3 of Set 12 | khalkhal
# Processing Record 4 of Set 12 | sragen
# Processing Record 5 of Set 12 | abu dhabi
# Processing Record 6 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 7 of Set 12 | leshukonskoye
# Processing Record 8 of Set 12 | alexandria
# Processing Record 9 of Set 12 | lakselv
# Processing Record 10 of Set 12 | kaeo
# Processing Record 11 of Set 12 | monrovia
# Processing Record 12 of Set 12 | ilhabela
# Processing Record 13 of Set 12 | paamiut
# Processing Record 14 of Set 12 | belmonte
# Processing Record 15 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 12 | teseney
# Processing Record 17 of Set 12 | dunedin
# Processing Record 18 of Set 12 | avon park
# Processing Record 19 of Set 12 | leh
# Processing Record 20 of Set 12 | moron
# Processing Record 21 of Set 12 | geraldton
# Processing Record 22 of Set 12 | mbandaka
# Processing Record 23 of Set 12 | zavyalovo
# Processing Record 24 of Set 12 | mujiayingzi
# Processing Record 25 of Set 12 | el reno
# Processing Record 26 of Set 12 | vestmannaeyjar
# Processing Record 27 of Set 12 | tutoia
# Processing Record 28 of Set 12 | praia da vitoria
# Processing Record 29 of Set 12 | annau
# Processing Record 30 of Set 12 | mahibadhoo
# Processing Record 31 of Set 12 | muros
# Processing Record 32 of Set 12 | davidson
# Processing Record 33 of Set 12 | nyurba
# Processing Record 34 of Set 12 | natchitoches
# Processing Record 35 of Set 12 | sept-iles
# Processing Record 36 of Set 12 | yulara
# Processing Record 37 of Set 12 | healdsburg
# Processing Record 38 of Set 12 | pilar
# Processing Record 39 of Set 12 | palmer
# Processing Record 40 of Set 12 | sao jose da coroa grande
# Processing Record 41 of Set 12 | kirkwall
# Processing Record 42 of Set 12 | mecca
# Processing Record 43 of Set 12 | vaitape
# Processing Record 44 of Set 12 | balad
# Processing Record 45 of Set 12 | taos
# Processing Record 46 of Set 12 | ruidoso
# Processing Record 47 of Set 12 | havelock
# Processing Record 48 of Set 12 | belen
# Processing Record 49 of Set 12 | berck
# Processing Record 50 of Set 12 | viedma
# Processing Record 1 of Set 13 | riachao
# Processing Record 2 of Set 13 | rincon
# Processing Record 3 of Set 13 | pudem
# Processing Record 4 of Set 13 | nuuk
# Processing Record 5 of Set 13 | uryupinsk
# Processing Record 6 of Set 13 | karlskoga
# Processing Record 7 of Set 13 | colborne
# Processing Record 8 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 13 | skjervoy
# Processing Record 10 of Set 13 | kandrian
# Processing Record 11 of Set 13 | korla
# Processing Record 12 of Set 13 | qasigiannguit
# Processing Record 13 of Set 13 | soledade
# Processing Record 14 of Set 13 | palmas bellas
# Processing Record 15 of Set 13 | mandapam
# Processing Record 16 of Set 13 | acarau
# Processing Record 17 of Set 13 | avera
# Processing Record 18 of Set 13 | pedernales
# Processing Record 19 of Set 13 | broome
# Processing Record 20 of Set 13 | goderich
# Processing Record 21 of Set 13 | koutiala
# Processing Record 22 of Set 13 | sukhothai
# Processing Record 23 of Set 13 | dawlatabad
# Processing Record 24 of Set 13 | coquimbo
# Processing Record 25 of Set 13 | huangchuan
# Processing Record 26 of Set 13 | cerqueira cesar
# Processing Record 27 of Set 13 | tooele
# Processing Record 28 of Set 13 | hun
# Processing Record 29 of Set 13 | berlevag
# Processing Record 30 of Set 13 | honiara
# Processing Record 31 of Set 13 | huanren
# Processing Record 32 of Set 13 | seoul
# Processing Record 33 of Set 13 | half moon bay
# Processing Record 34 of Set 13 | perivolion
# Processing Record 35 of Set 13 | alofi
# Processing Record 36 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 37 of Set 13 | fort saint james
# Processing Record 38 of Set 13 | jalu
# Processing Record 39 of Set 13 | port blair
# Processing Record 40 of Set 13 | konosha
# Processing Record 41 of Set 13 | asau
# Processing Record 42 of Set 13 | tuyen quang
# Processing Record 43 of Set 13 | rawson
# Processing Record 44 of Set 13 | aksarka
# Processing Record 45 of Set 13 | santa adelia
# Processing Record 46 of Set 13 | puerto carreno
# Processing Record 47 of Set 13 | niitsu
# Processing Record 48 of Set 13 | plettenberg bay
# Processing Record 49 of Set 13 | labuhan
# Processing Record 50 of Set 13 | mount gambier
# Processing Record 1 of Set 14 | peniche
# Processing Record 2 of Set 14 | san luis
# Processing Record 3 of Set 14 | tilichiki
# Processing Record 4 of Set 14 | ishigaki
# Processing Record 5 of Set 14 | juybar
# Processing Record 6 of Set 14 | dhola
# Processing Record 7 of Set 14 | zomin
# Processing Record 8 of Set 14 | yerbogachen
# Processing Record 9 of Set 14 | kupang
# Processing Record 10 of Set 14 | talara
# Processing Record 11 of Set 14 | yeppoon
# Processing Record 12 of Set 14 | koslan
# Processing Record 13 of Set 14 | rancho palos verdes
# Processing Record 14 of Set 14 | bubaque
# Processing Record 15 of Set 14 | isangel
# Processing Record 16 of Set 14 | podyuga
# Processing Record 17 of Set 14 | saint-augustin
# Processing Record 18 of Set 14 | hami
# Processing Record 19 of Set 14 | itaituba
# Processing Record 20 of Set 14 | novaya ladoga
# Processing Record 21 of Set 14 | khudumelapye
# Processing Record 22 of Set 14 | foumbot
# Processing Record 23 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 14 | klyuchi
# Processing Record 25 of Set 14 | nalhati
# Processing Record 26 of Set 14 | igrim
# Processing Record 27 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 14 | kandi
# Processing Record 29 of Set 14 | miri
# Processing Record 30 of Set 14 | kirovsk
# Processing Record 31 of Set 14 | mutoko
# Processing Record 32 of Set 14 | salamiyah
# Processing Record 33 of Set 14 | castro marim
# Processing Record 34 of Set 14 | angoram
# Processing Record 35 of Set 14 | tessalit
# Processing Record 36 of Set 14 | grindavik
# Processing Record 37 of Set 14 | ous
# Processing Record 38 of Set 14 | nikolayevka
# Processing Record 39 of Set 14 | maldonado
# Processing Record 40 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 41 of Set 14 | hoquiam
# Processing Record 42 of Set 14 | salalah
# Processing Record 43 of Set 14 | oparino
# Processing Record 44 of Set 14 | vila franca do campo
# Processing Record 45 of Set 14 | vila
# Processing Record 46 of Set 14 | norsup
# Processing Record 47 of Set 14 | tura
# Processing Record 48 of Set 14 | robertson
# Processing Record 49 of Set 14 | jaciara
# Processing Record 50 of Set 14 | sistranda
# Processing Record 1 of Set 15 | balotra
# Processing Record 2 of Set 15 | faya
# Processing Record 3 of Set 15 | apiai
# Processing Record 4 of Set 15 | tamandare
# Processing Record 5 of Set 15 | pahrump
# Processing Record 6 of Set 15 | imeni poliny osipenko
# Processing Record 7 of Set 15 | okakarara
# Processing Record 8 of Set 15 | santa maria
# Processing Record 9 of Set 15 | srednekolymsk
# Processing Record 10 of Set 15 | soe
# Processing Record 11 of Set 15 | santa lucia
# Processing Record 12 of Set 15 | havre
# Processing Record 13 of Set 15 | bengkulu
# Processing Record 14 of Set 15 | mwense
# Processing Record 15 of Set 15 | palmas
# Processing Record 16 of Set 15 | salisbury
# Processing Record 17 of Set 15 | kaseda
# Processing Record 18 of Set 15 | santa cruz
# Processing Record 19 of Set 15 | maiduguri
# Processing Record 20 of Set 15 | matara
# Processing Record 21 of Set 15 | riberalta
# Processing Record 22 of Set 15 | pavlohrad
# Processing Record 23 of Set 15 | grafton
# Processing Record 24 of Set 15 | tomatlan
# Processing Record 25 of Set 15 | kloulklubed
# Processing Record 26 of Set 15 | kedrovyy
# Processing Record 27 of Set 15 | garowe
# Processing Record 28 of Set 15 | san quintin
# Processing Record 29 of Set 15 | te anau
# Processing Record 30 of Set 15 | hongjiang
# Processing Record 31 of Set 15 | dali
# Processing Record 32 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 33 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 34 of Set 15 | surt
# Processing Record 35 of Set 15 | danielskuil
# Processing Record 36 of Set 15 | forestville
# Processing Record 37 of Set 15 | mananjary
# Processing Record 38 of Set 15 | nador
# Processing Record 39 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 40 of Set 15 | winnemucca
# Processing Record 41 of Set 15 | agadir
# Processing Record 42 of Set 15 | ahraura
# Processing Record 43 of Set 15 | beira
# Processing Record 44 of Set 15 | rudnya
# Processing Record 45 of Set 15 | nelson bay
# Processing Record 46 of Set 15 | pangody
# Processing Record 47 of Set 15 | kalmunai
# Processing Record 48 of Set 15 | karasjok
# Processing Record 49 of Set 15 | okato
# Processing Record 50 of Set 15 | diu
# Processing Record 1 of Set 16 | tirumullaivasal
# Processing Record 2 of Set 16 | erechim
# Processing Record 3 of Set 16 | sola
# Processing Record 4 of Set 16 | ulaangom
# Processing Record 5 of Set 16 | vao
# Processing Record 6 of Set 16 | buraydah
# Processing Record 7 of Set 16 | lithakia
# Processing Record 8 of Set 16 | ithaca
# Processing Record 9 of Set 16 | sorong
# Processing Record 10 of Set 16 | beringovskiy
# Processing Record 11 of Set 16 | nadadores
# Processing Record 12 of Set 16 | nantucket
# Processing Record 13 of Set 16 | kindu
# Processing Record 14 of Set 16 | bangassou
# Processing Record 15 of Set 16 | caravelas
# Processing Record 16 of Set 16 | mishkino
# Processing Record 17 of Set 16 | mayumba
# Processing Record 18 of Set 16 | tornio
# Processing Record 19 of Set 16 | channel-port aux basques
# Processing Record 20 of Set 16 | zhigansk
# Processing Record 21 of Set 16 | borba
# Processing Record 22 of Set 16 | beyneu
# Processing Record 23 of Set 16 | atbasar
# Processing Record 24 of Set 16 | windsor
# Processing Record 25 of Set 16 | dawei
# Processing Record 26 of Set 16 | anadyr
# Processing Record 27 of Set 16 | ushtobe
# Processing Record 28 of Set 16 | villanueva de cordoba
# Processing Record 29 of Set 16 | meulaboh
# Processing Record 30 of Set 16 | zeya
# Processing Record 31 of Set 16 | zalegoshch
# Processing Record 32 of Set 16 | pringsewu
# Processing Record 33 of Set 16 | vardo
# Processing Record 34 of Set 16 | frontera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create the DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Albany  42.6001  -73.9662     58.17        48         100
# 1           Lebu -37.6167  -73.6500     52.45        90           0
# 2      Busselton -33.6500  115.3333     65.37        73          64
# 3       Buchanan   5.8808  -10.0467     79.56        86         100
# 4        Ushuaia -54.8000  -68.3000     38.86        81          20
# 5  Gualdo Tadino  43.2317   12.7810     46.42        86          59
# 6       Thompson  55.7435  -97.8558     26.76        86         100
# 7    Henties Bay -22.1160   14.2845     62.76        69           0
# 8       Hermanus -34.4187   19.2345     58.80        85          27
# 9     Banda Aceh   5.5577   95.3222     82.31        76         100
#
#    Wind Speed Current Description Country                 Date
# 0        2.04     overcast clouds      US  2022-05-02 00:43:19
# 1       15.10           clear sky      CL  2022-05-02 00:42:42
# 2        2.75       broken clouds      AU  2022-05-02 00:40:57
# 3        7.27       moderate rain      LR  2022-05-02 00:51:21
# 4        6.91          few clouds      AR  2022-05-02 00:46:30
# 5        2.13       broken clouds      IT  2022-05-02 00:51:22
# 6       12.66     overcast clouds      CA  2022-05-02 00:51:22
# 7        8.66           clear sky      NA  2022-05-02 00:51:23
# 8        9.37    scattered clouds      ZA  2022-05-02 00:48:24
# 9       11.27     overcast clouds      ID  2022-05-02 00:51:23

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# %%
# Export the city_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
